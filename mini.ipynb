# %% [markdown]
# complete mini pipeline
# Build full pipeline:
#
# Dataset
# DataLoader
# Model
# Loss
# Optimizer
# Training loop

# %%
import torch as nn
import torch.nn as nn
from torch.utils.data import DataLoader,Dataset

# %%
class MyDataset(Dataset):
    def __init__(self):
        self.x = torch.tensor([[1.0],[2.0],[3.0],[4.0]])
        self.y = torch.tensor([[2.0],[4.0],[6.0],[8.0]])

    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]

# %%
import torch

dataset=MyDataset()
dataloader=DataLoader(dataset,batch_size=2,shuffle=True)

# %%
import torch
import torch.nn as nn

class MyModel(nn.Module):   # ✅ fixed name
    def __init__(self):
        super().__init__()  # ✅ fixed
        self.linear = nn.Linear(1,1)

    def forward(self, x):
        return self.linear(x)

model = MyModel()   # ✅ matches class name

loss_fn = nn.MSELoss()

optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

# %%
for epoch in range(20):

    for x, y in dataloader:

        # Forward pass
        y_pred = model(x)

        # Loss
        loss = loss_fn(y_pred, y)

        # Clear gradients
        optimizer.zero_grad()

        # Backward
        loss.backward()

        # Update weights
        optimizer.step()

    print(f"Epoch {epoch}, Loss: {loss.item()}")
# Out:
# Epoch 0, Loss: 16.967092514038086
# Epoch 1, Loss: 15.320589065551758
# Epoch 2, Loss: 2.615143299102783
# Epoch 3, Loss: 3.6930935382843018
# Epoch 4, Loss: 2.6992578506469727
# Epoch 5, Loss: 1.3592430353164673
# Epoch 6, Loss: 0.13828592002391815
# Epoch 7, Loss: 0.40117064118385315
# Epoch 8, Loss: 0.1577015370130539
# Epoch 9, Loss: 0.14315173029899597
# Epoch 10, Loss: 0.012670570984482765
# Epoch 11, Loss: 0.06124253198504448
# Epoch 12, Loss: 0.0135852275416255
# Epoch 13, Loss: 0.046118415892124176
# Epoch 14, Loss: 0.09553074836730957
# Epoch 15, Loss: 0.0163461621850729
# Epoch 16, Loss: 0.09015966206789017
# Epoch 17, Loss: 0.08936259150505066
# Epoch 18, Loss: 0.030778201296925545
# Epoch 19, Loss: 0.027266696095466614

# %%
for name, param in model.named_parameters():
    print(name, param.data)
# Out:
# linear.weight tensor([[1.8161]])
# linear.bias tensor([0.5488])

# %%
import torch

# %%
x=torch.tensor(2.0, requires_grad=True)
y=x**3+5*x
y.backward()
print(x.grad)
# Out:
# tensor(17.)

# %%
import torch
from torch.utils.data import Dataset, DataLoader

class MyDataset(Dataset):
    def __init__(self):
        self.x = torch.tensor([[1.0],[2.0],[3.0],[4.0]])
        self.y = torch.tensor([[2.0],[4.0],[6.0],[8.0]])

    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]

# %%
import torch.nn as nn
class Mymodel(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear=nn.Linear(1,1)

    def forward(self,x):
        return self.linear(x)

# %%
model=Mymodel()
loss_fn=nn.MSELoss()
import torch.optim as optim
optimizer=torch.optim.SGD(model.parameters(),lr=0.01)

# %%
import torch
import torch.nn as nn

x = torch.tensor([[1.0],[2.0],[3.0],[4.0]])
y = torch.tensor([[3.0],[6.0],[9.0],[12.0]])

model = nn.Linear(1,1)

loss_fn = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

for epoch in range(50):

    # Forward
    y_pred = model(x)

    # Loss
    loss = loss_fn(y_pred, y)

    # Backward
    optimizer.zero_grad()
    loss.backward()

    # Update
    optimizer.step()

    # Print
    if epoch % 10 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item()}")

for name, param in model.named_parameters():
    print(name, param.data)
# Out:
# Epoch 0, Loss: 61.68574905395508
# Epoch 10, Loss: 1.9138840436935425
# Epoch 20, Loss: 0.3489384651184082
# Epoch 30, Loss: 0.29102200269699097
# Epoch 40, Loss: 0.27311021089553833
# weight tensor([[2.5777]])
# bias tensor([1.2408])

# %%
import torch
from torch import nn
from torch.utils.data import dataset,dataloader

# %%
class MyDataset(Dataset):
    def __init__(self):
        self.x = torch.tensor([[1.0],[2.0],[3.0],[4.0]])
        self.y = torch.tensor([[3.0],[6.0],[9.0],[12.0]])

    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]

# %%
dataset=MyDataset()
dataloader=DataLoader(dataset,batch_size=2,shuffle=True)

# %%
model = nn.Linear(1,1)
loss_fn = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(),lr=0.01)

# %%
for epoch in range(50):
    for x_batch,y_batch in dataloader:
        y_pred=model(x_batch)
        loss=loss_fn(y_pred,y_batch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f"Epoch {epoch}, Loss: {loss.item()}")
# Out:
# Epoch 0, Loss: 53.367958068847656
# Epoch 1, Loss: 26.01201629638672
# Epoch 2, Loss: 4.21747350692749
# Epoch 3, Loss: 6.439098834991455
# Epoch 4, Loss: 1.2246804237365723
# Epoch 5, Loss: 1.7752742767333984
# Epoch 6, Loss: 0.23975566029548645
# Epoch 7, Loss: 0.8818552494049072
# Epoch 8, Loss: 0.3807886242866516
# Epoch 9, Loss: 0.2743883430957794
# Epoch 10, Loss: 0.21598030626773834
# Epoch 11, Loss: 0.1826145052909851
# Epoch 12, Loss: 0.15508802235126495
# Epoch 13, Loss: 0.31164753437042236
# Epoch 14, Loss: 0.1425361931324005
# Epoch 15, Loss: 0.31272539496421814
# Epoch 16, Loss: 0.3106807470321655
# Epoch 17, Loss: 0.05761467665433884
# Epoch 18, Loss: 0.3043416142463684
# Epoch 19, Loss: 0.09933605790138245
# Epoch 20, Loss: 0.2914741039276123
# Epoch 21, Loss: 0.28769588470458984
# Epoch 22, Loss: 0.11894256621599197
# Epoch 23, Loss: 0.0568513348698616
# Epoch 24, Loss: 0.05487372353672981
# Epoch 25, Loss: 0.2821831703186035
# Epoch 26, Loss: 0.11637192219495773
# Epoch 27, Loss: 0.08404193818569183
# Epoch 28, Loss: 0.26307934522628784
# Epoch 29, Loss: 0.2734551429748535
# Epoch 30, Loss: 0.10862433910369873
# Epoch 31, Loss: 0.2545419931411743
# Epoch 32, Loss: 0.25135886669158936
# Epoch 33, Loss: 0.24825383722782135
# Epoch 34, Loss: 0.07326459139585495
# Epoch 35, Loss: 0.09933848679065704
# Epoch 36, Loss: 0.06774673610925674
# Epoch 37, Loss: 0.06395961344242096
# Epoch 38, Loss: 0.2502996623516083
# Epoch 39, Loss: 0.047746602445840836
# Epoch 40, Loss: 0.23756761848926544
# Epoch 41, Loss: 0.2327401340007782
# Epoch 42, Loss: 0.17435534298419952
# Epoch 43, Loss: 0.17183029651641846
# Epoch 44, Loss: 0.221830353140831
# Epoch 45, Loss: 0.09306081384420395
# Epoch 46, Loss: 0.09049023687839508
# Epoch 47, Loss: 0.08844375610351562
# Epoch 48, Loss: 0.06267549842596054
# Epoch 49, Loss: 0.04239475354552269

# %%
for(name, param) in model.named_parameters():
    print(name, param.data)
# Out:
# weight tensor([[2.7163]])
# bias tensor([0.8427])
