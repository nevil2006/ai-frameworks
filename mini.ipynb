# %% [markdown]
# complete mini pipeline
# Build full pipeline:
#
# Dataset
# DataLoader
# Model
# Loss
# Optimizer
# Training loop

# %%
import torch as nn
import torch.nn as nn
from torch.utils.data import DataLoader,Dataset

# %%
class MyDataset(Dataset):
    def __init__(self):
        self.x = torch.tensor([[1.0],[2.0],[3.0],[4.0]])
        self.y = torch.tensor([[2.0],[4.0],[6.0],[8.0]])

    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]

# %%
import torch

dataset=MyDataset()
dataloader=DataLoader(dataset,batch_size=2,shuffle=True)

# %%
import torch
import torch.nn as nn

class MyModel(nn.Module):   # ✅ fixed name
    def __init__(self):
        super().__init__()  # ✅ fixed
        self.linear = nn.Linear(1,1)

    def forward(self, x):
        return self.linear(x)

model = MyModel()   # ✅ matches class name

loss_fn = nn.MSELoss()

optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

# %%
for epoch in range(20):

    for x, y in dataloader:

        # Forward pass
        y_pred = model(x)

        # Loss
        loss = loss_fn(y_pred, y)

        # Clear gradients
        optimizer.zero_grad()

        # Backward
        loss.backward()

        # Update weights
        optimizer.step()

    print(f"Epoch {epoch}, Loss: {loss.item()}")
# Out:
# Epoch 0, Loss: 9.898941993713379
# Epoch 1, Loss: 6.605325222015381
# Epoch 2, Loss: 4.987527847290039
# Epoch 3, Loss: 2.511622667312622
# Epoch 4, Loss: 1.570860505104065
# Epoch 5, Loss: 1.1980252265930176
# Epoch 6, Loss: 0.02905287593603134
# Epoch 7, Loss: 0.35136887431144714
# Epoch 8, Loss: 0.024141330271959305
# Epoch 9, Loss: 0.014923278242349625
# Epoch 10, Loss: 0.06873562932014465
# Epoch 11, Loss: 0.06835036724805832
# Epoch 12, Loss: 0.04876461997628212
# Epoch 13, Loss: 0.09352479875087738
# Epoch 14, Loss: 0.06580909341573715
# Epoch 15, Loss: 0.08867403864860535
# Epoch 16, Loss: 0.0853678435087204
# Epoch 17, Loss: 0.029657598584890366
# Epoch 18, Loss: 0.0352538600564003
# Epoch 19, Loss: 0.06463995575904846

# %%
for name, param in model.named_parameters():
    print(name, param.data)
# Out:
# linear.weight tensor([[1.8191]])
# linear.bias tensor([0.5331])

# %%
import torch

# %%
x=torch.tensor(2.0, requires_grad=True)
y=x**3+5*x
y.backward()
print(x.grad)
# Out:
# tensor(17.)

# %%
import torch
from torch.utils.data import Dataset, DataLoader

class MyDataset(Dataset):
    def __init__(self):
        self.x = torch.tensor([[1.0],[2.0],[3.0],[4.0]])
        self.y = torch.tensor([[2.0],[4.0],[6.0],[8.0]])

    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]

# %%
import torch.nn as nn
class Mymodel(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear=nn.Linear(1,1)

    def forward(self,x):
        return self.linear(x)

# %%
model=Mymodel()
loss_fn=nn.MSELoss()
import torch.optim as optim
optimizer=torch.optim.SGD(model.parameters(),lr=0.01)

# %%
import torch
import torch.nn as nn

x = torch.tensor([[1.0],[2.0],[3.0],[4.0]])
y = torch.tensor([[3.0],[6.0],[9.0],[12.0]])

model = nn.Linear(1,1)

loss_fn = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

for epoch in range(50):

    # Forward
    y_pred = model(x)

    # Loss
    loss = loss_fn(y_pred, y)

    # Backward
    optimizer.zero_grad()
    loss.backward()

    # Update
    optimizer.step()

    # Print
    if epoch % 10 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item()}")

for name, param in model.named_parameters():
    print(name, param.data)
# Out:
# Epoch 0, Loss: 53.96262741088867
# Epoch 10, Loss: 1.3974995613098145
# Epoch 20, Loss: 0.03743434697389603
# Epoch 30, Loss: 0.0021721087396144867
# Epoch 40, Loss: 0.0011897170916199684
# weight tensor([[3.0273]])
# bias tensor([-0.0812])

# %%
import torch
from torch import nn
from torch.utils.data import dataset,dataloader

# %%
class MyDataset(Dataset):
    def __init__(self):
        self.x = torch.tensor([[1.0],[2.0],[3.0],[4.0]])
        self.y = torch.tensor([[3.0],[6.0],[9.0],[12.0]])

    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]

# %%
dataset=MyDataset()
dataloader=DataLoader(dataset,batch_size=2,shuffle=True)

# %%
model = nn.Linear(1,1)
loss_fn = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(),lr=0.01)

# %%
for epoch in range(50):
    for x_batch,y_batch in dataloader:
        y_pred=model(x_batch)
        loss=loss_fn(y_pred,y_batch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f"Epoch {epoch}, Loss: {loss.item()}")
# Out:
# Epoch 0, Loss: 31.15404510498047
# Epoch 1, Loss: 29.684560775756836
# Epoch 2, Loss: 1.2155663967132568
# Epoch 3, Loss: 6.0519700050354
# Epoch 4, Loss: 3.783365249633789
# Epoch 5, Loss: 0.5825634002685547
# Epoch 6, Loss: 0.4120033383369446
# Epoch 7, Loss: 1.0643118619918823
# Epoch 8, Loss: 0.6923268437385559
# Epoch 9, Loss: 0.06104539334774017
# Epoch 10, Loss: 0.38511431217193604
# Epoch 11, Loss: 0.2687176764011383
# Epoch 12, Loss: 0.07155738025903702
# Epoch 13, Loss: 0.46354803442955017
# Epoch 14, Loss: 0.43415939807891846
# Epoch 15, Loss: 0.19480213522911072
# Epoch 16, Loss: 0.18714654445648193
# Epoch 17, Loss: 0.08138063549995422
# Epoch 18, Loss: 0.07976391166448593
# Epoch 19, Loss: 0.17868201434612274
# Epoch 20, Loss: 0.31982022523880005
# Epoch 21, Loss: 0.41280463337898254
# Epoch 22, Loss: 0.31039300560951233
# Epoch 23, Loss: 0.4007325768470764
# Epoch 24, Loss: 0.3020941913127899
# Epoch 25, Loss: 0.12938648462295532
# Epoch 26, Loss: 0.0753791481256485
# Epoch 27, Loss: 0.07313159108161926
# Epoch 28, Loss: 0.3722987473011017
# Epoch 29, Loss: 0.36673393845558167
# Epoch 30, Loss: 0.15235182642936707
# Epoch 31, Loss: 0.10795174539089203
# Epoch 32, Loss: 0.3711033761501312
# Epoch 33, Loss: 0.2752569019794464
# Epoch 34, Loss: 0.3550880551338196
# Epoch 35, Loss: 0.10916641354560852
# Epoch 36, Loss: 0.26597151160240173
# Epoch 37, Loss: 0.3430406451225281
# Epoch 38, Loss: 0.33657702803611755
# Epoch 39, Loss: 0.13878080248832703
# Epoch 40, Loss: 0.13535304367542267
# Epoch 41, Loss: 0.09640306234359741
# Epoch 42, Loss: 0.08889173716306686
# Epoch 43, Loss: 0.2471781075000763
# Epoch 44, Loss: 0.062063489109277725
# Epoch 45, Loss: 0.09193728864192963
# Epoch 46, Loss: 0.06124038249254227
# Epoch 47, Loss: 0.30488866567611694
# Epoch 48, Loss: 0.09088759869337082
# Epoch 49, Loss: 0.08314037322998047

# %%
for(name, param) in model.named_parameters():
    print(name, param.data)
# Out:
# weight tensor([[2.6685]])
# bias tensor([0.9976])
